# %%
dur = 1.5
freq = 220
sr = 441000

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# dur        float    1.5
# freq       int      220
# sr         int      441000

# %%
# %who
# Out:
# dur	 freq	 sr

# %%
sr = 44100

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# dur        float    1.5
# freq       int      220
# sr         int      44100

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ###### arange() populates an array from 0 to dur with stepsize 1/sr

# %%
arange?

# %%
t = arange(0, dur, 1/sr)

# %%
t
# Out:
# array([  0.00000000e+00,   2.26757370e-05,   4.53514739e-05, ...,
#          1.49993197e+00,   1.49995465e+00,   1.49997732e+00])

# %%
type(t)
# Out:
# numpy.ndarray

# %%
t.dtype
# Out:
# dtype('float64')

# %%
t.size
# Out:
# 66150

# %%
sig = sin(2 * pi * freq * t)

# %%
sig
# Out:
# array([ 0.        ,  0.03133956,  0.06264832, ..., -0.09389555,
#        -0.06264832, -0.03133956])

# %%
plot(sig[:200])

# %%
sig = sin(2 * pi * freq * 2 * t)
sig2 = cos(2 * pi * freq * 5 * t)

# %%
plot(sig[:400], sig2[:400], 'm-')

# %%
plot?

# %%
plot(sig[:200], 'g-', linewidth=4)
plot(sig2[:200], 'bo', linewidth=1)

# %%
sig = sin(2*pi*freq*t) + (sin(2*pi*freq*3*t)/3)

# %%
plot(sig[:200])

# %%
sig = (sin(2*pi*freq*t))

# %%
plot(sig[:200])

# %%
freq = array((220, 300))

# %%
sig = sin(2 * pi * freq * t.reshape(-1, 1))

# %%
sig
# Out:
# array([[ 0.        ,  0.        ],
#        [ 0.03133956,  0.04272974],
#        [ 0.06264832,  0.08538143],
#        ...,
#        [-0.09389555, -0.12787716],
#        [-0.06264832, -0.08538143],
#        [-0.03133956, -0.04272974]])

# %%
plot(sig[:600])
ylim(-1.1,1.1)
# Out:
# (-1.1, 1.1)

# %%
freq = 220
sigSaw=0
for x in range(1,22):
    sigSaw += sin(2*pi*(freq*x)*t)/x

# %%
plot(sigSaw[:1000])

# %%
freq = 220
sigSqr=0
for x in range(1,22,2):
    sigSqr += sin(2*pi*(freq*x)*t)/x

# %%
plot(sigSqr[:1000])

# %%
sig=0
freq=220
sig = sin(2*pi*freq*t)

# %%
plot(sigSaw[:1000], 'g-')
plot(sigSqr[:1000], 'r-')
plot(sig[:1000], 'b-', linewidth=2)

# %%
sig2 = cos(2*pi*freq*7*t)
plot(sigSqr[:400],sig2[:400])
