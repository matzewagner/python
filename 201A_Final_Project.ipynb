# %% [markdown]
# # Morphing of audio signals

# %% [markdown]
# #### by Matthias Wagner, March 2015
# for MAT201A

# %%
# %pylab inline
from IPython.display import HTML
from scipy.io import wavfile
from IPython.display import YouTubeVideo
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# For my final project, I experimented with morphing of sounds with the use of sinusoidal modeling. My initial motivation was to extend my sonic palette, and morphing was something that I had not done before. To this end, I employ the Loris library, which was specifically designed for this purpose.

# %% [markdown]
# ## Sinusoidal modeling

# %% [markdown]
# The morphing of audio signals is different in both procedure and result from a simple amplitude crossfade. Whereas the latter also describes a transition from one sound to another, the human ear can generally clearly detect two different sounds - one appearing, while the other disappears. A sinusoidal model analyzes the spectral content of the signals, and interpolates between them. Ideally, this leads to the effect of transitioning between different signals as one smooth sound.

# %% [markdown]
# In more detail, in order to attain a sinusoidal model of a signal, we first perform a spectral analysis via the Fourier transform. As a morph between signals unfolds over time, we need to make use of the discrete Fourier transform (preferably FFT). From the magnitude and phase spectrum we can infer peaks, representing sinusoids that are present at that frequency. The sinusoidal model treats the spectrum as a **sum of time-varying sinusoids** (meaning sinusoids, where frequency and amplitude can vary over time).

# %%
voice_spectrum = imread('spear_voice.png')
figure(figsize=(15,15))
figtext(0.3, 0.27, 'sinusoidal model of a human singing, created with SPEAR', fontsize=14)
axis('off')
imshow(voice_spectrum)

# %% [markdown]
# Peak **tracks** are created, which interpolate between the changing sinusoids in each window. The size of the analysis window also determines the frequency resolution, and therefor has significant impact on the result. The algorithm for defining a track between sinusoids needs to take into account how stable frequency, amplitude and phase are over successive frames. These tracks are then resynthesized as a sum of sine oscillators, to represent the original signal. The actual morph is a time based interpolation between the tracks of multiple signals.

# %% [markdown]
# ## Loris

# %% [markdown]
# The Loris library generally follows this procedure, but expands on it with the *Reassigned Bandwidth-Enhanced Additive Sound Model*. I short, this embodies that each track has a certain bandwidth that exceeds that of a pure sinewave, and includes some amount of noise in addition. Loris offers an extensive yet simple to use toolkit for analyzing signals and morphing between them.

# %% [markdown]
# ### Analysis

# %% [markdown]
# In order to obtain a satisfactory model of a sound, several things have to be considered during the analysis process. First, we should give estimates of a fundamental frequency and the duration of the sound to make the computations more effective. We can set for frequency resolution, as well as the frequency drift parameter. The latter predetermines how much sinusoids can deviate over time, and is usually set to half of the frequency resolution. In addition to setting a window size, we can also select the hop-time, which constitutes the overlap of analysis windows. Finally, we can use functions to specify frequency floor and amplitude floor, which can help lessening unwanted noise.

# %% [markdown]
# ###### C++ code for sound analysis using the loris library

# %% [raw]
# // Sinusoidal analyzer
# // by Matthias Wagner, March 2015, for MAT201A
# // makes use of open source software package Loris
# // (http://www.cerlsoundgroup.org/Loris)
#
# // Takes a soundfile and analyses the spectral content. Outputs an .sdif
# // and a resynthesized .aiff file
#
#     #include <stdio.h>
#     #include <string.h>
#     #include <loris.h>
#
#     int main( void )
#     {
#         const double FUNDAMENTAL = 98.0;
#                        /* in Hz */
#         const unsigned long BUFSZ = 44100 * 6;
#                        /* approx. dur in seconds */
#
#         PartialList * partials = NULL;
#         double samples[ BUFSZ ];
#         double sr;
#         unsigned int nsamps;
#
#         /* import the samples */
#         nsamps = importAiff("Piano.aiff", samples, BUFSZ, &sr);
#
#         /* set frequency resolution and frequency drift */
#         analyzer_configure( .2 * FUNDAMENTAL, FUNDAMENTAL );
#         analyzer_setFreqDrift( .3 * FUNDAMENTAL );
#
#         /* set hop time and crop time in seconds */
#        analyzer_setHopTime( 0.008 );
#        analyzer_setCropTime( 2.0 * analyzer_getHopTime() );
#
#         /* set frequency and amplitude floor */
#         analyzer_setFreqFloor( FUNDAMENTAL*0.9 );
#         analyzer_setAmpFloor( -80 );
#
#         /* analyze and store partials */
#         partials = createPartialList();
#         analyze( samples, nsamps, sr, partials );
#
#         /* export to SDIF file */
#         exportSdif("Piano.sdif", partials );
#
#         /* synthesize */
#         memset( samples, 0, BUFSZ * sizeof(double) );
#         nsamps = synthesize( partials, samples, BUFSZ, sr );
#
#         /* set bandwidth parameters */
#         analyzer_storeNoBandwidth();
#         /* export samples to AIFF file */
#         exportAiff( "Piano_synth.aiff", samples, nsamps, sr, 16 );
#
#         /* cleanup */
#         destroyPartialList( partials );
#
#
#     printf("Hello World!\n");
#     return 0;
# }

# %% [markdown]
# ### Morph

# %% [markdown]
# In addition to the analysis and morph functions, Loris includes several audio editing options, which can be performed prior to the actual morph.  These include the ability to align the onsets of the signals, as well as a time stretching algorithm, which can be performed at an arbitrary number of breakpoints within the audio sample. There is also a pitch shifting function that provides the possibility of bringing signals with different fundamentals closer together. The morph function in Loris simply asks for time values that determine when and over what duration the morph takes place. However, we can define 3 different envelopes, to morph frequency, amplitude and noisiness independently.

# %% [markdown]
# ###### C++ code for sound morphing using the loris library

# %% [raw]
# // Sinusoidal Sound Morpher
# // by Matthias Wagner, March 2015, for MAT201A
# // makes use of open source software package Loris
# // (http://www.cerlsoundgroup.org/Loris)
#
# // Takes two .sdif files, and creates a .aiff of a timed morph
# // between the two signals. Offers time aligning and pitch shifting
# // functionality
#
#
# #include "loris.h"
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <strings.h>
#
# int main( void )
# {
#    #define BUFSZ (10*44100)
#    double samples[ BUFSZ ];
#    unsigned int N = 0;
#
#
#    PartialList * sampleA = createPartialList();
#    PartialList * sampleB = createPartialList();
#    LinearEnvelope * reference = 0;
#    LinearEnvelope * pitchenv = createLinearEnvelope();
#
#    LinearEnvelope * morphenv = createLinearEnvelope();
#    PartialList * mrph = createPartialList();
#
#    // times for stretching the samples
#    // initial times
#    double sampleB_times[] = {0, 10.};
#    double sampleA_times[] = {0, 6.};
#    // target times
#    double tgt_times[] = {0, 10.};
#
#    /* import the raw sampleA partials */
#    printf( "importing sampleA partials\n" );
#    importSdif( "Piano.sdif", sampleA );
#
#    /* channelize and distill */
#    printf( "distilling\n" );
#    /* enevlope to track estimated fundamental frequency
#       between 2 values, at a sampling rate */
#    reference = createF0Estimate( sampleA, 60, 150, 0.01 );
#    /* label partials */
#    channelize( sampleA, reference, 1 );
#    /* combine partials with common frequencies */
#    distill( sampleA );
#    destroyLinearEnvelope( reference );
#    reference = 0;
#
#    /* shift pitch of sampleA partials */
#    printf( "shifting pitch of sampleA partials up/down by ... cents\n" );
#    linearEnvelope_insertBreakpoint( pitchenv, 0, -100 );
#    shiftPitch( sampleA, pitchenv );
#    destroyLinearEnvelope( pitchenv );
#    pitchenv = 0;
#
#    /* import the raw sampleB partials */
#    printf( "importing sampleB partials\n" );
#    importSdif( "Sine.sdif", sampleB );
#
#    /* channelize and distill */
#    printf( "distilling\n" );
#    /* enevlope to track estimated fundamental frequency
#       between 2 values, at a sampling rate */
#    reference = createF0Estimate( sampleB, 60, 150, 0.01 );
#    /* label partials */
#    channelize( sampleB, reference, 1 );
#    /* combine partials with common frequencies */
#    distill( sampleB );
#    destroyLinearEnvelope( reference );
#    reference = 0;
#
#    /* align onsets */
#    printf( "dilating sounds to align onsets\n" );
#    dilate( sampleA, sampleA_times, tgt_times, 2 );
#    dilate( sampleB, sampleB_times, tgt_times, 2 );
#
#    /* perform morph */
#    printf( "morphing sampleAinet with sampleB\n" );
#    /* sample A (starting time) */
#    linearEnvelope_insertBreakpoint( morphenv, 1.0, 0 );
#    /* sample B (end time) */
#    linearEnvelope_insertBreakpoint( morphenv, 9.0, 1 );
#    /* morph from one sample to the other, using envelopes for
#       frequency, amplitude and noisyness */
#    morph( sampleB, sampleA, morphenv, morphenv, morphenv, mrph );
#
#    /* synthesize and export samples */
#    printf( "synthesizing %lu morphed partials\n",
#            partialList_size( mrph ) );
#    N = synthesize( mrph, samples, BUFSZ, 44100 );
#    exportAiff( "morph.aiff", samples, N, 44100, 16 );
#
#    /* cleanup */
#    destroyPartialList( mrph );
#    destroyPartialList( sampleA );
#    destroyPartialList( sampleB );
#    destroyLinearEnvelope( morphenv );
#
#    printf( "Done, bye.\n\n" );
#    return 0;
# }

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Analysis

# %% [markdown]
# ###### original piano sample

# %%
h = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196773749&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196773749&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample1 = wavfile.read('piano_c2.wav')
Pxx, freqs, bins, im = specgram(sample1, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of piano sample', fontsize=12)
show()

# %% [markdown]
# ###### piano sinusoidal model

# %%
h1 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196775037&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h1)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196775037&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample2 = wavfile.read('piano_c2_synth.wav')
Pxx, freqs, bins, im = specgram(sample2, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of piano sinusoidal model', fontsize=12)
show()

# %% [markdown]
# Sounds very close, apart from some changes in the attack of the note and some artifacts artifacts.

# %% [markdown]
# ###### original concert bass drum

# %%
h2 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196776647&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h2)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196776647&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample3 = wavfile.read('BDr.wav')
Pxx, freqs, bins, im = specgram(sample3, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of concert bass drum sample', fontsize=12)
show()

# %% [markdown]
# ###### concert bass drum sinusoidal model

# %%
h3 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196776881&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h3)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196776881&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample4 = wavfile.read('BDr_synth.wav')
Pxx, freqs, bins, im = specgram(sample4, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of concert bass drum sinusoidal model', fontsize=12)
show()

# %% [markdown]
# Issues become more apparent with this *quasi-harmonic* sound. The program (and/or programmer) fails to faithfully reconstruct the attack together with the cluttered low frequency partials.

# %% [markdown]
# ###### original cymbal hits

# %%
h4 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777335&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h4)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777335&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample5 = wavfile.read('CymbalHits.wav')
Pxx, freqs, bins, im = specgram(sample5, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of cymbal hits sample', fontsize=12)
show()

# %% [markdown]
# ###### cymbal hits sinusoidal model

# %%
h5 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777405&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_userfalse&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h5)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777405&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_userfalse&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample6 = wavfile.read('CymbalHits_synth.wav')
Pxx, freqs, bins, im = specgram(sample6, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of cymbal hits sinusoidal model', fontsize=12)
show()

# %% [markdown]
# This fairly noisy cymbal sound is quite faithfully recreated through sinusoidal modeling. To my surprise, this took very little tweaking.

# %% [markdown]
# ###### original timpani roll

# %%
h6 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777798&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h6)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777798&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample7 = wavfile.read('TimpRoll.wav')
Pxx, freqs, bins, im = specgram(sample7, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of timpani roll sample', fontsize=12)
show()

# %% [markdown]
# ###### timpani roll sinusoidal model

# %%
h7 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777846&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h7)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196777846&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample8 = wavfile.read('TimpRoll_synth.wav')
Pxx, freqs, bins, im = specgram(sample8, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of timpani roll sinusoidal model', fontsize=12)
show()

# %% [markdown]
# Probably due to the high number of transients in the signal, the sinusoidal model produces a noticeable amount of noise, and some of the definition of the original sound gets smeared. This effect was lessened somewhat with the use of the noiseFloor() function, and attempts at different window sizes. As for the latter, there always seemed to be a trade off between definition and noise.

# %% [markdown]
# ### Morphing

# %% [markdown]
# ###### sine and piano

# %%
h8 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/playlists/91017078&amp;auto_play=false&amp;hide_related=truee&amp;show_comments=false&amp;show_user=falsee&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h8)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/playlists/91017078&amp;auto_play=false&amp;hide_related=truee&amp;show_comments=false&amp;show_user=falsee&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample9 = wavfile.read('SineHitsToPiano.wav')
Pxx, freqs, bins, im = specgram(sample9, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of sine morphing into piano', fontsize=12)
show()

# %%
sr, sample10 = wavfile.read('PianoHitsToSine.wav')
Pxx, freqs, bins, im = specgram(sample10, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of piano morphing into sine', fontsize=12)
show()

# %% [markdown]
# For reference. As expected, the transition between a largely periodic signal and a primitive sine wave goes smooth as butter.

# %% [markdown]
# ###### original metal plate

# %%
h9 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196778950&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h9)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196778950&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample11 = wavfile.read('MetalLong.wav')
Pxx, freqs, bins, im = specgram(sample11, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of metal plate sample', fontsize=12)
show()

# %% [markdown]
# ###### metal plate and piano

# %%
h10 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779121&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h10)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779121&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample12 = wavfile.read('MtoP_stretch.wav')
Pxx, freqs, bins, im = specgram(sample12, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of metal plate morphing into piano', fontsize=12)
show()

# %% [markdown]
# These two fairly unrelated sounds also don't make for a convincing morph. One major problem here is also where and for how long the morph takes place.

# %% [markdown]
# ###### metal plate to sine

# %%
h11 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779288&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h11)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779288&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample13 = wavfile.read('MetalToSine.wav')
Pxx, freqs, bins, im = specgram(sample13, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of metal plate morphing into sine', fontsize=12)
show()

# %% [markdown]
# ###### metal plate to concert bass drum

# %%
h12 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779539&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h12)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779539&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample14 = wavfile.read('MtoBDr.wav')
Pxx, freqs, bins, im = specgram(sample14, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of metal plate to concert bass drum', fontsize=12)
show()

# %% [markdown]
# ###### metal plate to conert bass drum with pitch shift

# %%
h13 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779616&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h13)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196779616&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample15 = wavfile.read('MtoBdr_shiftdown.wav')
Pxx, freqs, bins, im = specgram(sample15, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of metal plate morphing into concert bass drum, pitch shifted', fontsize=12)
show()

# %% [markdown]
# In the last two examples, some artifacts become apparent over the duration of the morph. The two signals here are largely at opposites of the frequency spectrum, and one can hear the sine waves trying to catch up with the morph.

# %% [markdown]
# ###### concert bass drum to metal plate (same pitch estimate)

# %%
h15 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196780652&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h15)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/tracks/196780652&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample16 = wavfile.read('BDrtoM_samePitchEstimate.wav')
Pxx, freqs, bins, im = specgram(sample16, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of concert bass drum morphing into metal plate', fontsize=12)
show()

# %% [markdown]
# Performing the morph in the reverse order actually makes for some satisfying effect. On this morph, both samples are treated as if they shared the same fundamental pitch (unlike the previous examples, where I tried to define the bass drum lower than the cymbal.

# %% [markdown]
# ###### piano to metal plate, various morph lengths

# %% [markdown]
# 4 examples: morphs over 1, 2 & 3 seconds, and 3 second morph of a time stretched signal

# %%
h14 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/playlists/91020370&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h14)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/playlists/91020370&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample17 = wavfile.read('PtoM1.0.wav')
Pxx, freqs, bins, im = specgram(sample17, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of piano morhping into metal plate, over 1 second', fontsize=12)
show()

# %%
sr, sample18 = wavfile.read('PtoM2.0.wav')
Pxx, freqs, bins, im = specgram(sample18, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of piano morhping into metal plate, over 2 seconds', fontsize=12)
show()

# %%
sr, sample19 = wavfile.read('PtoM3.0.wav')
Pxx, freqs, bins, im = specgram(sample19, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of piano morhping into metal plate, over 3 seconds', fontsize=12)
show()

# %%
sr, sample20 = wavfile.read('PtoM3.0_stretch.wav')
Pxx, freqs, bins, im = specgram(sample20, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of piano morhping into metal plate, over 3 seconds, pitch shifted', fontsize=12)
show()

# %% [markdown]
# ###### sine and cymbal

# %%
h16 = HTML("""<iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/playlists/91021806&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>""")
display(h16)
# Out:
# <iframe width="30%" height="100" scrolling="no" frameborder="no" src="https://w.soundcloud.com/player/?url=https%3A//api.soundcloud.com/playlists/91021806&amp;auto_play=false&amp;hide_related=true&amp;show_comments=false&amp;show_user=false&amp;show_reposts=false&amp;visual=true"></iframe>

# %%
sr, sample21 = wavfile.read('SineToCymbalHits.wav')
Pxx, freqs, bins, im = specgram(sample21, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of sine tones morphing into cymbal hits', fontsize=12)
show()

# %%
sr, sample22 = wavfile.read('CymbalHitsToSine.wav')
Pxx, freqs, bins, im = specgram(sample22, 1024, Fs=sr, noverlap=1, cmap=cm.gist_heat)
figtext(0.1, 0.01, 'spectrum of cymbal hits morphing into sine tones', fontsize=12)
show()

# %% [markdown]
#  Morphs between sounds of relatively short duration sometimes tend to sound more like an amplitude crossfade of the signals, and are therefor somewhat lacking the morph effect. Still, interesting results can be created, when the sounds are played repeatedly, and the morph takes place over several iterations. In this case, I find the transsitions between sine and cymbal especially interesting, and surprisingly real.

# %% [markdown]
# ###### Links:

# %% [markdown]
# http://www.cerlsoundgroup.org/Loris

# %% [markdown]
# http://web.media.mit.edu/~tristan/Classes/MAS.945/Papers/Technical/Serra_SMS_97.pdf
